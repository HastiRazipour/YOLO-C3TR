# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import gdown
url = 'https://drive.google.com/uc?id=1G61lBk7_qMBkvVXO4S4wsAOa19HOr_QH'
output = 'RDD_v1.zip'
gdown.download(url, output, quiet=False)

# %%
# !mkdir -p /content/RDD
# !unzip /content/RDD_v1.zip -d /content/RDD
# !sed -i 's|train: /kaggle/input/irdd-v1/train/images|train: /content/RDD/train/images|g' /content/RDD/data.yaml
# !sed -i 's|val: /kaggle/input/irdd-v1/valid/images|val: /content/RDD/valid/images|g' /content/RDD/data.yaml
# Out:
# Archive:  /content/drive/MyDrive/Data_RDD/RDD_v1.zip
#   inflating: /content/RDD/data.yaml
#   inflating: /content/RDD/train/images/0005d060-IMG_20240504_173415_augmented_0.jpg
#   inflating: /content/RDD/train/images/003d2dae-IMG_20240503_061111.jpg
#   inflating: /content/RDD/train/images/0048e22d-IMG_20240504_163204.jpg
#   inflating: /content/RDD/train/images/006d8521-IMG_20240504_164029.jpg
#   inflating: /content/RDD/train/images/00e7cb3b-IMG_20240503_062129_augmented_0.jpg
#   inflating: /content/RDD/train/images/00f0f051-IMG_20240504_172713_augmented_1.jpg
#   inflating: /content/RDD/train/images/010fbd71-IMG_20240504_173704_1_augmented_1.jpg
#   inflating: /content/RDD/train/images/011f9714-IMG_20240503_064313_augmented_0.jpg
#   inflating: /content/RDD/train/images/01aec0b0-IMG_20240504_174253_augmented_0.jpg
#   inflating: /content/RDD/train/images/020d8cff-IMG_20240503_062352.jpg
#   inflating: /content/RDD/train/images/027ba633-IMG_20240504_174310_augmented_0.jpg
# ...

# %%
# !pip install timm ultralytics
# !git clone https://github.com/HastiRazipour/YOLO-C3TR
# %cd /content/YOLO-C3TR/src/
# !pip install -r requirements.txt
# !pwd
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 922.6/922.6 kB 25.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 103.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 85.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 58.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 16.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 93.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !python train.py --img 640 --batch 16 --epochs 60 --data /content/RDD/data.yaml --cfg /content/yolov5/models/yolov5s.yaml --device 0

import shutil

# Define the source directory and the destination zip file
source_dir = "/content/YOLO-C3TR/src/runs"
zip_file = "/content/transrormer_yolo_data.zip"

# Create a zip archive
shutil.make_archive(zip_file.replace('.zip', ''), 'zip', source_dir)

# Move the zip file to Google Drive
shutil.move(zip_file, "pass to your drive")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-03-10 17:17:46.119881: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741627066.364247    3774 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...
